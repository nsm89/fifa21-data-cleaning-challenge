# %%
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("C:\\Users\\Admin\\Documents\\fifa21_raw_data_v2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# #### Wage Column
# - remove 'K' and '€';
# - replace 'K' with '000';
# - change datatype to integer;
# - indicate currency on column name.

# %%
df['Wage'] = df['Wage'].str.replace('K', '000')
df['Wage'] = df['Wage'].str.replace('€', '')
df['Wage'] = df['Wage'].astype(str).astype(int)
df['Wage'].dtype
# Out:
# dtype('int32')

# %%
df['Wage'].head()
# Out:
# 0    560000
# 1    220000
# 2    125000
# 3    370000
# 4    270000
# Name: Wage, dtype: int32

# %%
df.rename(columns={'Wage': 'Wage (€)'}).head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# #### Height Column
# - remove 'cm', and ' " ' from height;
# - filter inches from cm;
# - convert inches to cm;
# - change data type to integer;
# - rename column to "Height (cm)".

# %%
df['Height'] = df['Height'].str.replace('cm', '')
df['Height'] = df['Height'].str.replace('"', '')

inches_list = []
indexes = []

for i in range(len(df['Height'])):
    if "'" in df.loc[i, 'Height']:
        indexes.append(i)
        inches_list.append(df.loc[i, 'Height'])

inches_list[0]
# Out:
# "6'2"

# %%
def heightToCm(height):
    feet, inches = height.split("'")
    feet = int(feet)
    inches = int(inches)
    height_in_cm = (feet * 30.48) + (inches * 2.54)
    return height_in_cm

# %%
for i in indexes:
    newHeight = heightToCm(df.loc[i, 'Height'])
    df.loc[i, 'Height'] = newHeight

# %%
df['Height'] = df['Height'].astype(int)
df.rename(columns={'Height': 'Height (cm)'}).head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# #### Weight Column
# - remove 'kg' and 'lbs';
# - convert pounds to kgs;
# - convert column to int;
# - rename column to 'Weight (kg).

# %%
df['Weight'] = df['Weight'].str.replace('kg', '')

lbs_list = []
lbs_indexes = []

for i in range(len(df['Weight'])):
    if "lbs" in df.loc[i, 'Weight']:
        lbs_indexes.append(i)
        lbs_list.append(df.loc[i, 'Weight'])

lbs_list[:3]
# Out:
# ['183lbs', '179lbs', '183lbs']

# %%
def poundsToKg(weight):
    lbs = weight.replace('lbs', '')
    lbs = int(lbs)
    lbs_in_kg = lbs * 0.45
    return lbs_in_kg

# %%
for i in lbs_indexes:
    newWeight = poundsToKg(df.loc[i, 'Weight'])
    df.loc[i, 'Weight'] = newWeight

# %%
df['Weight'] = df['Weight'].astype(int)
df.rename(columns={'Weight': 'Weight (kg)'}).head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# #### Club Column
# - remove extra spaces in the column.

# %%
df['Club'] = df['Club'].str.replace('\n', '')
df['Club'].head()
# Out:
# 0           FC Barcelona
# 1               Juventus
# 2        Atlético Madrid
# 3        Manchester City
# 4    Paris Saint-Germain
# Name: Club, dtype: object

# %% [markdown]
# #### Value Column
# - remove '€', 'K' and 'M';
# - change datatype to integer;
# - add appropriate zeros to the figures;
# - specify currency in column name.

# %%
df.loc[1, 'Value'][1: -1]
# Out:
# '63'

# %%
for i in range(len(df['Value'])):
    if df.loc[i, 'Value'][1] == '0':
        df.loc[i, 'Value'] = 0
    else:
        df.loc[i, 'Value'] = df.loc[i, 'Value'][1:-1]

# %%
df['Value'] = df['Value'].astype(float)

# %%
df['Value'] = df['Value'] * 1000000

# %%
df['Value'] = df['Value'].astype(int)

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
df.rename(columns={'Value': 'Value (€)'}).head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# #### Stars in Columns
# - remove stars in the columns
# - change to numerical datatype

# %%
stars = ['W/F', 'SM', 'IR']

df.loc[1, 'W/F']
# Out:
# '4 ★'

# %%
for column in stars:
    for i in range(len(df)):
        df.loc[i, column] = df.loc[i, column][0]
    df[column] = df[column].astype(int)

# %% [markdown]
# #### Hits Column
# - replace 'K' with 000
# - change to numerical datatype

# %%
for i in range(len(df)):
    if isinstance(df.loc[i, 'Hits'], str) and df.loc[i, 'Hits'][-1] == 'K':
        df.loc[i, 'Hits'] = float(df.loc[i, 'Hits'][:-1]) * 1000

# %%
df['Hits'] = df['Hits'].fillna(0)

# %%
df['Hits'] = df['Hits'].astype(int)

# %% [markdown]
# #### Release Clause Column
# - remove characters
# - change to numerical datatype
# - change column name

# %%
df.loc[0, 'Release Clause'][1: -1]
# Out:
# '138.4'

# %%
for i in range(len(df['Release Clause'])):
    if df.loc[i, 'Release Clause'][1] == '0':
        df.loc[i, 'Release Clause'] = 0
    else:
        df.loc[i, 'Release Clause'] = df.loc[i, 'Release Clause'][1:-1]

# %%
df['Release Clause'] = df['Release Clause'].astype(float)

# %%
df['Release Clause'] = df['Release Clause'] * 1000000

# %%
df['Release Clause'] = df['Release Clause'].astype(int)

# %%
df.rename(columns={'Release Clause': 'Release Clause (€)'}).head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# #### Age Column
# - change datatype to integer

# %%
df['Age'].describe()
# Out:
# count    18979.000000
# mean        25.194109
# std          4.710520
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         29.000000
# max         53.000000
# Name: Age, dtype: float64

# %%
df['Age'] = df['Age'].apply(np.int32)

# %%
df['Age'].head()
# Out:
# 0    33
# 1    35
# 2    27
# 3    29
# 4    28
# Name: Age, dtype: int32

# %% [markdown]
# #### PhotoUrl Column
# - replace 'com' with 'net'

# %%
df['photoUrl'].head()
# Out:
# 0    https://cdn.sofifa.com/players/158/023/21_60.png
# 1    https://cdn.sofifa.com/players/020/801/21_60.png
# 2    https://cdn.sofifa.com/players/200/389/21_60.png
# 3    https://cdn.sofifa.com/players/192/985/21_60.png
# 4    https://cdn.sofifa.com/players/190/871/21_60.png
# Name: photoUrl, dtype: object

# %%
df['photoUrl'] = df['photoUrl'].str.replace('com', 'net')

# %%
df.drop(['Loan Date End'], axis=1).head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.net/players/158/023/21_60.png
# 1  https://cdn.sofifa.net/players/020/801/21_60.png
# 2  https://cdn.sofifa.net/players/200/389/21_60.png
# 3  https://cdn.sofifa.net/players/192/985/21_60.png
# 4  https://cdn.sofifa.net/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
df.to_csv('fifa21_cleaned.csv', index=False)
